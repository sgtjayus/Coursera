# %%
###TEST

#!/usr/bin/env python
import pandas as pd
import pandas.io.data
from pandas import Series, DataFrame

import matplotlib.pyplot as plt
import matplotlib as mpl
mpl.rc('figure', figsize=(8, 7))
#take out for PyCharm
# %matplotlib inline  

import datetime
from datetime import date

def gen_periods(startyear,endyear):
    periods = []

    for i in range(startyear,endyear):
        newperiod = [date(i,1,1)]
        periods = periods + newperiod

    if endyear-1 == date.today().year :
        periods.append(date.today())

    for i in range(0,len(periods)):
        periods[i] = periods[i].isoformat()
    
    return periods

def DR_corr(tickers,startdate,enddate):
    data = DataFrame()

    for i in tickers:
        x = pd.io.data.get_data_yahoo(i,startdate,enddate)['Adj Close']
        x.name = i
        data = pd.concat([data,x], 1)

    data = data.pct_change()
    return data.corr()

def DR_corr_tables(tickers,periods):
    for i in range(0,len(periods)-1):
        print periods[i]
        print DR_corr(tickers,periods[i],periods[i+1])
        print '\n'

#TODO label x-axis w/ periods
def DR_corrwith(ticker1,ticker2,periods):
    corrwith = []
    tickers  = [ticker1,ticker2]
    for i in range(0,len(periods)-1):
        corrwith.append(DR_corr(tickers,periods[i],periods[i+1]).iloc[0][ticker2])
    corrwith = DataFrame(data = corrwith, index = periods[1:], columns = ["DR_corr"])
    return corrwith
        
tickers = ["vbmfx", "SPY"]
periods = gen_periods(2001,2016)

#DR_corr_tables(tickers,periods)
x = DR_corrwith("djp","xle",periods)
print x
x.plot()
plt.show
#print DR_corr(tickers,"2013-01-01","2015-01-01")[0:2]["SPY"]
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-1-84da08090b52> in <module>()
#      60
#      61 #DR_corr_tables(tickers,periods)
# ---> 62 x = DR_corrwith("djp","xle",periods)
#      63 print x
#      64 x.plot()
#
# <ipython-input-1-84da08090b52> in DR_corrwith(ticker1, ticker2, periods)
#      52     tickers  = [ticker1,ticker2]
#      53     for i in range(0,len(periods)-1):
# ---> 54         corrwith.append(DR_corr(tickers,periods[i],periods[i+1]).iloc[0][ticker2])
#      55     corrwith = DataFrame(data = corrwith, index = periods[1:], columns = ["DR_corr"])
#      56     return corrwith
#
# <ipython-input-1-84da08090b52> in DR_corr(tickers, startdate, enddate)
#      34
#      35     for i in tickers:
# ---> 36         x = pd.io.data.get_data_yahoo(i,startdate,enddate)['Adj Close']
#      37         x.name = i
#      38         data = pd.concat([data,x], 1)
#
# //anaconda/lib/python2.7/site-packages/pandas/io/data.pyc in get_data_yahoo(symbols, start, end, retry_count, pause, adjust_price, ret_index, chunksize)
#     405     """
#     406     return _get_data_from(symbols, start, end, retry_count, pause,
# --> 407                           adjust_price, ret_index, chunksize, 'yahoo')
#     408
#     409
#
# //anaconda/lib/python2.7/site-packages/pandas/io/data.pyc in _get_data_from(symbols, start, end, retry_count, pause, adjust_price, ret_index, chunksize, source)
#     351     # If a single symbol, (e.g., 'GOOG')
#     352     if isinstance(symbols, (compat.string_types, int)):
# --> 353         hist_data = src_fn(symbols, start, end, retry_count, pause)
#     354     # Or multiple symbols, (e.g., ['GOOG', 'AAPL', 'MSFT'])
#     355     elif isinstance(symbols, DataFrame):
#
# //anaconda/lib/python2.7/site-packages/pandas/io/data.pyc in _get_hist_yahoo(sym, start, end, retry_count, pause)
#     198            '&g=d' +
#     199            '&ignore=.csv')
# --> 200     return _retry_read_url(url, retry_count, pause, 'Yahoo!')
#     201
#     202
#
# //anaconda/lib/python2.7/site-packages/pandas/io/data.pyc in _retry_read_url(url, retry_count, pause, name)
#     175
#     176     raise IOError("after %d tries, %s did not "
# --> 177                   "return a 200 for url %r" % (retry_count, name, url))
#     178
#     179
#
# IOError: after 3 tries, Yahoo! did not return a 200 for url 'http://ichart.finance.yahoo.com/table.csv?s=djp&a=0&b=1&c=2001&d=0&e=1&f=2002&g=d&ignore=.csv'

# %%
###STAGING

#!/usr/bin/env python
import pandas as pd
import pandas.io.data
from pandas import Series, DataFrame

import matplotlib.pyplot as plt
import matplotlib as mpl
mpl.rc('figure', figsize=(8, 7))
#take out for PyCharm
# %matplotlib inline  

import datetime
from datetime import date

def gen_periods(startyear,endyear):
    periods = []

    for i in range(startyear,endyear):
        newperiod = [date(i,1,1)]
        periods = periods + newperiod

    if endyear-1 == date.today().year :
        periods.append(date.today())

    for i in range(0,len(periods)):
        periods[i] = periods[i].isoformat()
    
    return periods

def DR_corr(tickers,startdate,enddate):
    data = DataFrame()

    for i in tickers:
        x = pd.io.data.get_data_yahoo(i,startdate,enddate)['Adj Close']
        x.name = i
        data = pd.concat([data,x], 1)

    data = data.pct_change()
    return data.corr()

def DR_corr_tables(tickers,periods):
    for i in range(0,len(periods)-1):
        print periods[i]
        print DR_corr(tickers,periods[i],periods[i+1])
        print '\n'

def DR_corrwith(ticker1,ticker2,periods):
    corrwith = []
    tickers  = [ticker1,ticker2]
    for i in range(0,len(periods)-1):
        corrwith.append(DR_corr(tickers,periods[i],periods[i+1]).iloc[0][ticker2])
    corrwith = DataFrame(data = corrwith, index = periods[1:], columns = ["DR_corr"])
    return corrwith
        
#INIT 
tickers = ["vbmfx", "SPY"]
periods = gen_periods(2001,2016)

#CALL
#x = DR_corr_tables(tickers,periods)
#x = DR_corrwith("vbmfx","SPY",periods)
print x
#x.plot()
#plt.show
# Out:
# None
